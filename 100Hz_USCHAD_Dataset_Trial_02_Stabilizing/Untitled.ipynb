# %%
trial = trial_value_set[trial_index]
# Out:
# Train data shape:  (390, 500, 3)
# Test data shape:  (136, 500, 3)
# Train label shape:  (390, 12)
# Test label shape:  (136, 12)
# Train on 390 samples, validate on 136 samples
# Epoch 1/100
#  - 12s - loss: 2.5932 - acc: 0.0974 - val_loss: 2.4476 - val_acc: 0.1544
# Epoch 2/100
#  - 5s - loss: 2.3134 - acc: 0.2077 - val_loss: 2.3542 - val_acc: 0.1324
# Epoch 3/100
#  - 5s - loss: 2.1622 - acc: 0.2205 - val_loss: 2.2095 - val_acc: 0.1838
# Epoch 4/100
#  - 5s - loss: 2.0621 - acc: 0.2718 - val_loss: 2.0748 - val_acc: 0.2426
# Epoch 5/100
#  - 5s - loss: 2.0075 - acc: 0.2462 - val_loss: 1.9455 - val_acc: 0.3015
# Epoch 6/100
#  - 5s - loss: 1.9316 - acc: 0.2974 - val_loss: 1.8551 - val_acc: 0.3015
# Epoch 7/100
#  - 5s - loss: 1.8933 - acc: 0.2974 - val_loss: 1.7760 - val_acc: 0.3088
# Epoch 8/100
#  - 5s - loss: 1.8804 - acc: 0.2821 - val_loss: 1.6914 - val_acc: 0.3235
# Epoch 9/100
#  - 5s - loss: 1.8338 - acc: 0.3256 - val_loss: 1.6377 - val_acc: 0.3235
# Epoch 10/100
# ...
