# %% [markdown]
# ## Window - 250

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
window_size = 250

f = open('Supervised-MLP-Baseline_Learning_Summary_Window-'+str(window_size)+'.pckl','rb')
supervised_mlp_temp = pickle.load(f)
f.close()

f = open('Supervised_Learning_Summary_Window-'+str(window_size)+'.pckl','rb')
supervised_temp = pickle.load(f)
f.close()

f = open('Unsupervised_Learning_LS_Summary_Window-'+str(window_size)+'.pckl','rb')
unsupervised_ls_temp = pickle.load(f)
f.close()

f = open('Unsupervised_Learning_TS-LS_Summary_Window-'+str(window_size)+'.pckl','rb')
unsupervised_ts_ls_temp = pickle.load(f)
f.close()

f = open('Transfer_Learning_LS_Summary_Window-'+str(window_size)+'.pckl','rb')
transfer_ls_temp = pickle.load(f)
f.close()

f = open('Transfer_Learning_Fine-Tune_Summary_Window-'+str(window_size)+'.pckl','rb')
transfer_all_temp = pickle.load(f)
f.close()

f = open('Unsupervised_Transfer_Learning_TS-LS-Fine-Tune_Summary_Window-'+str(window_size)+'.pckl','rb')
unsup_transfer_ts_ls_all_temp = pickle.load(f)
f.close()

f = open('KA-Dual_T-5_Summary_Window-'+str(window_size)+'.pckl','rb')
kadual_temp = pickle.load(f)
f.close()

f = open('KA_T-5_Summary_Window-'+str(window_size)+'.pckl','rb')
ka_temp = pickle.load(f)
f.close()

# %% [markdown]
# # Accuracy

# %%
plt.figure(figsize=(15,10))

acc = supervised_mlp_temp[0][np.arange(0,3,2)]
acc_mean = acc.max(axis=1).mean(axis=0, dtype=np.float64)
acc_std = acc.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10),acc_mean,acc_std, label = 'Hand Engineered - MLP',elinewidth=6,linewidth=6)

acc = supervised_temp[0][np.arange(0,3,2)]
acc_mean = acc.max(axis=1).mean(axis=0, dtype=np.float64)
acc_std = acc.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.003,acc_mean,acc_std, label = 'Supervised Learning',elinewidth=6,linewidth=6)
[np.arange(0,3,2)]
acc = unsupervised_ls_temp[0]
acc_mean = acc.max(axis=1).mean(axis=0, dtype=np.float64)
acc_std = acc.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.003,acc_mean,acc_std, label = 'Unsupervised Learning - LS',elinewidth=6,linewidth=6)

acc = unsupervised_ts_ls_temp[0][np.arange(0,3,2)]
acc_mean = acc.max(axis=1).mean(axis=0, dtype=np.float64)
acc_std = acc.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.006,acc_mean,acc_std, label = 'Unsupervised Learning - LS and TS',elinewidth=6,linewidth=6)

acc = transfer_ls_temp[0][np.arange(0,3,2)]
acc_mean = acc.max(axis=1).mean(axis=0, dtype=np.float64)
acc_std = acc.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.009,acc_mean,acc_std, label = 'Transfer Learning - LS',elinewidth=6,linewidth=6)

acc = transfer_all_temp[0][np.arange(0,3,2)]
acc_mean = acc.max(axis=1).mean(axis=0, dtype=np.float64)
acc_std = acc.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.006,acc_mean,acc_std, label = 'Transfer Learning - Fine-tune',elinewidth=6,linewidth=6)

acc = unsup_transfer_ts_ls_all_temp[0][np.arange(0,3,2)]
acc_mean = acc.max(axis=1).mean(axis=0, dtype=np.float64)
acc_std = acc.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.009,acc_mean,acc_std, label = 'Unsup Transfer - LS TS Fine-tune',elinewidth=6,linewidth=6)

acc = ka_temp[0][np.arange(0,3,2)]
acc_mean = acc.max(axis=1).mean(axis=0, dtype=np.float64)
acc_std = acc.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.012,acc_mean,acc_std, label = 'KA - Dual',elinewidth=6,linewidth=6)

acc = kadual_temp[0][np.arange(0,3,2)]
acc_mean = acc.max(axis=1).mean(axis=0, dtype=np.float64)
acc_std = acc.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.012,acc_mean,acc_std, label = 'KA - Dual Fine-tune',elinewidth=6,linewidth=6)

plt.legend(loc='lower right', prop={'size': 20})
plt.xticks(np.arange(0.10,0.61,0.10),np.arange(10,61,10,dtype=int),fontsize=20)
plt.xlabel('Percentage of training data',fontsize=20)
plt.ylabel('Accuracy',fontsize=20)
plt.xlim((0.05,0.65))
plt.ylim((0.40,0.725))
plt.grid()
plt.show()

# %% [markdown]
# # Precision

# %%
plt.figure(figsize=(15,10))

prec = supervised_mlp_temp[1][2][np.arange(0,3,2)]
prec_mean =  prec.max(axis=1).mean(axis=0, dtype=np.float64)
prec_std = prec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10),prec_mean,prec_std, label = 'Hand Engineered - MLP',elinewidth=6,linewidth=6)

prec = supervised_temp[1][2][np.arange(0,3,2)]
prec_mean =  prec.max(axis=1).mean(axis=0, dtype=np.float64)
prec_std = prec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.003,prec_mean,prec_std, label = 'Supervised Learning',elinewidth=6,linewidth=6)

prec = unsupervised_ls_temp[1][2][np.arange(0,3,2)]
prec_mean =  prec.max(axis=1).mean(axis=0, dtype=np.float64)
prec_std = prec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.003,prec_mean,prec_std, label = 'Unsupervised Learning - LS',elinewidth=6,linewidth=6)

prec = unsupervised_ts_ls_temp[1][2][np.arange(0,3,2)]
prec_mean =  prec.max(axis=1).mean(axis=0, dtype=np.float64)
prec_std = prec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.006,prec_mean,prec_std, label = 'Unsupervised Learning - LS and TS',elinewidth=6,linewidth=6)

prec = transfer_ls_temp[1][2][np.arange(0,3,2)]
prec_mean =  prec.max(axis=1).mean(axis=0, dtype=np.float64)
prec_std = prec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.009,prec_mean,prec_std, label = 'Transfer Learning - LS',elinewidth=6,linewidth=6)

prec = transfer_all_temp[1][2][np.arange(0,3,2)]
prec_mean =  prec.max(axis=1).mean(axis=0, dtype=np.float64)
prec_std = prec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.006,prec_mean,prec_std, label = 'Transfer Learning - Fine-tune',elinewidth=6,linewidth=6)

prec = unsup_transfer_ts_ls_all_temp[1][2][np.arange(0,3,2)]
prec_mean =  prec.max(axis=1).mean(axis=0, dtype=np.float64)
prec_std = prec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.009,prec_mean,prec_std, label = 'Unsup Transfer - LS TS Fine-tune',elinewidth=6,linewidth=6)

prec = ka_temp[1][2][np.arange(0,3,2)]
prec_mean =  prec.max(axis=1).mean(axis=0, dtype=np.float64)
prec_std = prec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.012,prec_mean,prec_std, label = 'KA - Dual',elinewidth=6,linewidth=6)

prec = kadual_temp[1][2][np.arange(0,3,2)]
prec_mean =  prec.max(axis=1).mean(axis=0, dtype=np.float64)
prec_std = prec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.012,prec_mean,prec_std, label = 'KA - Dual Fine-tune',elinewidth=6,linewidth=6)

plt.legend(loc='lower right', prop={'size': 20})
plt.xticks(np.arange(0.10,0.61,0.10),np.arange(10,61,10,dtype=int),fontsize=20)
plt.xlabel('Percentage of training data',fontsize=20)
plt.ylabel('Accuracy',fontsize=20)
plt.xlim((0.05,0.65))
plt.ylim((0.40,0.725))
plt.grid()
plt.show()

# %% [markdown]
# # Recall

# %%
plt.figure(figsize=(15,10))

rec = supervised_mlp_temp[2][2][np.arange(0,3,2)]
rec_mean =  rec.max(axis=1).mean(axis=0, dtype=np.float64)
rec_std = rec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10),rec_mean,rec_std, label = 'Hand Engineered - MLP',elinewidth=6,linewidth=6)

rec = supervised_temp[2][2][np.arange(0,3,2)]
rec_mean =  rec.max(axis=1).mean(axis=0, dtype=np.float64)
rec_std = rec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.003,rec_mean,rec_std, label = 'Supervised Learning',elinewidth=6,linewidth=6)

rec = unsupervised_ls_temp[2][2][np.arange(0,3,2)]
rec_mean =  rec.max(axis=1).mean(axis=0, dtype=np.float64)
rec_std = rec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.003,rec_mean,rec_std, label = 'Unsupervised Learning - LS',elinewidth=6,linewidth=6)

rec = unsupervised_ts_ls_temp[2][2][np.arange(0,3,2)]
rec_mean =  rec.max(axis=1).mean(axis=0, dtype=np.float64)
rec_std = rec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.006,rec_mean,rec_std, label = 'Unsupervised Learning - LS and TS',elinewidth=6,linewidth=6)

rec = transfer_ls_temp[2][2][np.arange(0,3,2)]
rec_mean =  rec.max(axis=1).mean(axis=0, dtype=np.float64)
rec_std = rec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.009,rec_mean,rec_std, label = 'Transfer Learning - LS',elinewidth=6,linewidth=6)

rec = transfer_all_temp[2][2][np.arange(0,3,2)]
rec_mean =  rec.max(axis=1).mean(axis=0, dtype=np.float64)
rec_std = rec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.006,rec_mean,rec_std, label = 'Transfer Learning - Fine-tune',elinewidth=6,linewidth=6)

rec = unsup_transfer_ts_ls_all_temp[2][2][np.arange(0,3,2)]
rec_mean =  rec.max(axis=1).mean(axis=0, dtype=np.float64)
rec_std = rec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.009,rec_mean,rec_std, label = 'Unsup Transfer - LS TS Fine-tune',elinewidth=6,linewidth=6)

rec = ka_temp[2][2][np.arange(0,3,2)]
rec_mean =  rec.max(axis=1).mean(axis=0, dtype=np.float64)
rec_std = rec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.012,rec_mean,rec_std, label = 'KA - Dual',elinewidth=6,linewidth=6)

rec = kadual_temp[2][2][np.arange(0,3,2)]
rec_mean =  rec.max(axis=1).mean(axis=0, dtype=np.float64)
rec_std = rec.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.012,rec_mean,rec_std, label = 'KA - Dual Fine-tune',elinewidth=6,linewidth=6)


plt.legend(loc='lower right', prop={'size': 20})
plt.xticks(np.arange(0.10,0.61,0.10),np.arange(10,61,10,dtype=int),fontsize=20)
plt.xlabel('Percentage of training data',fontsize=20)
plt.ylabel('Accuracy',fontsize=20)
plt.xlim((0.05,0.65))
plt.ylim((0.4,0.725))
plt.grid()
plt.show()

# %% [markdown]
# # F1

# %%
plt.figure(figsize=(15,10))

f1 = supervised_mlp_temp[3][2][np.arange(0,3,2)]
f1_mean =  f1.max(axis=1).mean(axis=0, dtype=np.float64)
f1_std = f1.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10),f1_mean,f1_std, label = 'Hand Engineered - MLP',elinewidth=6,linewidth=6)

f1 = supervised_temp[3][2][np.arange(0,3,2)]
f1_mean =  f1.max(axis=1).mean(axis=0, dtype=np.float64)
f1_std = f1.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.003,f1_mean,f1_std, label = 'Supervised Learning',elinewidth=6,linewidth=6)

f1 = unsupervised_ls_temp[3][2][np.arange(0,3,2)]
f1_mean =  f1.max(axis=1).mean(axis=0, dtype=np.float64)
f1_std = f1.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.003,f1_mean,f1_std, label = 'Unsupervised Learning - LS',elinewidth=6,linewidth=6)

f1 = unsupervised_ts_ls_temp[3][2][np.arange(0,3,2)]
f1_mean =  f1.max(axis=1).mean(axis=0, dtype=np.float64)
f1_std = f1.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.006,f1_mean,f1_std, label = 'Unsupervised Learning - LS and TS',elinewidth=6,linewidth=6)

f1 = transfer_ls_temp[3][2][np.arange(0,3,2)]
f1_mean =  f1.max(axis=1).mean(axis=0, dtype=np.float64)
f1_std = f1.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.009,f1_mean,f1_std, label = 'Transfer Learning - LS',elinewidth=6,linewidth=6)

f1 = transfer_all_temp[3][2][np.arange(0,3,2)]
f1_mean =  f1.max(axis=1).mean(axis=0, dtype=np.float64)
f1_std = f1.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.006,f1_mean,f1_std, label = 'Transfer Learning - Fine-tune',elinewidth=6,linewidth=6)

f1 = unsup_transfer_ts_ls_all_temp[3][2][np.arange(0,3,2)]
f1_mean =  f1.max(axis=1).mean(axis=0, dtype=np.float64)
f1_std = f1.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.009,f1_mean,f1_std, label = 'Unsup Transfer - LS TS Fine-tune',elinewidth=6,linewidth=6)

f1 = ka_temp[3][2][np.arange(0,3,2)]
f1_mean =  f1.max(axis=1).mean(axis=0, dtype=np.float64)
f1_std = f1.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)-0.012,f1_mean,f1_std, label = 'KA - Dual',elinewidth=6,linewidth=6)

f1 = kadual_temp[3][2][np.arange(0,3,2)]
f1_mean =  f1.max(axis=1).mean(axis=0, dtype=np.float64)
f1_std = f1.max(axis=1).std(axis=0, dtype=np.float64)
plt.errorbar(np.arange(0.10,0.61,0.10)+0.012,f1_mean,f1_std, label = 'KA - Dual Fine-tune',elinewidth=6,linewidth=6)

plt.legend(loc='lower right', prop={'size': 20})
plt.xticks(np.arange(0.10,0.61,0.10),np.arange(10,61,10,dtype=int),fontsize=20)
plt.xlabel('Percentage of training data',fontsize=20)
plt.ylabel('Accuracy',fontsize=20)
plt.xlim((0.05,0.65))
plt.ylim((0.35,0.725))
plt.grid()
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
labels = ['Walking Forward','Walking Left','Walking Right','Walking Upstairs','Walking Downstairs','Running Forward','Jumping Up','Sitting','Standing','Sleeping','Elevator Up','Elevator Down']
#Change
cm = supervised_mlp_temp[-1]
cm = supervised_temp[-1]
#cm = unsupervised_ls_temp[-1]
#cm = unsupervised_ts_ls_temp[-1]
#cm = transfer_ls_temp[-1]
#cm = transfer_all_temp[-1]
cm = unsup_transfer_ts_ls_all_temp[-1]
#cm = kadual_temp[-1]
#cm = ka_temp[-1]
##################################

cm = np.swapaxes(cm,0,2)
#Change
cm = cm[0]
c = cm.mean(axis=(0,1),dtype=np.float64)

c = np.around(c/ c.astype(np.float).sum(axis=1), decimals=5)
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
cax = ax.matshow(c,
                      cmap="OrRd")
fig.colorbar(cax)
cax.set_clim(0,1)
ax.set_xticks(np.arange(0,len(labels)))
ax.set_yticks(np.arange(0,len(labels)))
ax.set_xticklabels(labels,rotation='vertical',fontdict={'fontsize':10})
ax.set_yticklabels(labels,fontdict={'fontsize':10})
plt.xlabel('Predicted',fontsize='large')
plt.ylabel('True',fontsize='large')
plt.grid(alpha=0.25)
